# %% [markdown]
# ## Wrap Up: Etherscan

# %%
url = "https://etherscan.io/"

# %% [markdown]
# Simple GET request without JS.

# %%
import requests

html = requests.get(url)

html.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n    <title>Just a moment...</title>\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n    <meta name="robots" content="noindex,nofollow" />\n    <meta name="viewport" content="width=device-width,initial-scale=1" />\n    <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet" />\n    \n\n</head>\n<body class="no-js">\n    <div class="main-wrapper" role="main">\n    <div class="main-content">\n        <h1 class="zone-name-title h1">\n            <img class="heading-favicon" src="/favicon.ico"\n                 onerror="this.onerror=null;this.parentNode.removeChild(this)" />\n            etherscan.io\n        </h1>\n        <h2 class="h2" id="challenge-running">\n            Checking if the site connection is secure\n        </h2>\n        <noscript>\n            <div id="challenge-error-title">\n                <div class="h2">\n                    <span class="icon-wrapper">\n                        <div class="heading-icon warning-icon"></div>\n                    </span>\n                    <span id="challenge-error-text">\n                        Enable JavaScript and cookies to continue\n                    </span>\n                </div>\n            </div>\n        </noscript>\n        <div id="trk_jschal_js" style="display:none;background-image:url(\'/cdn-cgi/images/trace/captcha/nojs/transparent.gif?ray=7514118afd4bbba7\')"></div>\n        <div id="challenge-body-text" class="core-msg spacer">\n            etherscan.io needs to review the security of your connection before proceeding.\n        </div>\n        <form id="challenge-form" action="/?__cf_chl_f_tk=KAaWskA6D_1Nc4dHgWSDjKJu5BztdIg5z14Yo4owVpU-1664279917-0-gaNycGzNBz0" method="POST" enctype="application/x-www-form-urlencoded">\n            <input type="hidden" name="md" value="w55OHdE9d0UqYKpbjyUJMpb_rcH2R_rqnEv2fIE7T7Q-1664279917-0-AWv5sl5xcvpI1SV7OliN6IghcDNtXUW0RVf0jOW0-c2iJ7qm-hWW3QS0GcuscnmAR7knnKnuM_d25oyyDw2UnthcOFN6UwHHU5hgqDjL7fTbaCsfMnWMaHVs_8WQRwykOyaxduKZC7gWi_RT0bZLlLICXMQh5qo7wsIjJhjxr3IBlr2VcfBwlzvHBBf0u6cBstX2QlgewGQc63XMviJ7DO05Vb7lItJk6Z73cVITTnfFCePnHbBvYHuJoM1gg14yJxGMx5C2-0iMrxIZ1Ro091h1kWtuKItrHJ2iczer_FCEkBs6yISPELk_bb02sYjASy0ZBJ_Tte6_UX5GSaYnkD4qbqjhYB_MpJuNG3S51qOS0bTSbprZf6AhxgvPyRU1Y6vRIBCluTnTLVjQhGZoD1iFmh8W828m0oHNmASXAT_Pt3jP9vGhMb7oWbtX_5lAOCJuWUF9Cpi_FABr4xZ0Uy5iaulCoTliHyuGywUWu1N1Vsr4Dhzc27jOpzoysphJz7UoRzVQW8R4cuqXyn1yyxxucf4FUvk1BA2wQIm9ch2BkLRxVr5XOUOeJccZN13I_dYeU6JtipCsb8Q0jIM78QS7M5YmKbBrMDSWGMQB6-G34F6EJuoSrXj3GH8V4gGFJg" />\n            <input type="hidden" name="r" value="kPVkBGpGnIgByD6B5zN.vOyRvs7IE.igEINTu7KTJuo-1664279917-0-..."/>\n        </form>\n    </div>\n</div>\n<script>\n    (function(){\n        window._cf_chl_opt={\n            cvId: \'2\',\n            cType: \'interactive\',\n            cNounce: \'79783\',\n            cRay: \'7514118afd4bbba7\',\n            cHash: \'02d1231c125d26e\',\n            cUPMDTk: "\\/?__cf_chl_tk=KAaWskA6D_1Nc4dHgWSDjKJu5BztdIg5z14Yo4owVpU-1664279917-0-gaNycGzNBz0",\n            cFPWv: \'g\',\n            cTTimeMs: \'1000\',\n            cTplV: 4,\n            cTplB: \'cf\',\n            cRq: {\n                ru: \'aHR0cHM6Ly9ldGhlcnNjYW4uaW8v\',\n                ra: \'cHl0aG9uLXJlcXVlc3RzLzIuMjUuMQ==\',\n                rm: \'R0VU\',\n                d: \'...\',\n                t: \'MTY2NDI3OTkxNy4zMDMwMDA=\',\n                m: \'5K2SDYY41+YSbJmHq7S1A0XlmLwDx9z/XkJJrCsmXVU=\',\n                i1: \'YnaQxY9JcK/Da7twuE5qZQ==\',\n                i2: \'bpRyqTGlK+9FjRRnvmdbtQ==\',\n                zh: \'qb4aFuGlbJn/rUOkKXjUqElKDKE10jDqu5PE014OTwk=\',\n                uh: \'5GU+jYv2xJ+bCaE/ARmi/DORbiS/v56CW7E0TH4XWQk=\',\n                hh: \'YY5d6w6/MykdmyahOwkQ1jAVJALDXgufyWF08Z0bLMA=\',\n            }\n        };\n        var trkjs = document.createElement(\'img\');\n        trkjs.setAttribute(\'src\', \'/cdn-cgi/images/trace/capt ...

# %% [markdown]
# With custom headers.

# %%
hdr = {'User-Agent': 'Mozilla/5.0'}

html = requests.get(url, headers=hdr)

html.content
# Out:
# b'\n<!doctype html>\n<html lang="en">\n<head><title>\r\n\t Ethereum (ETH) Blockchain Explorer\r\n</title><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="author" content="etherscan.io" /><meta name="Description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /><meta name="keywords" content="ethereum, explorer, ether, search, blockchain, crypto, currency" /><meta name="format-detection" content="telephone=no" />\n<meta property="og:title" content=" Ethereum (ETH) Blockchain Explorer" /> <meta property="og:description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /> <meta property="og:type" content="website" /> <meta property="og:site_name" content="Ethereum (ETH) Blockchain Explorer" /> <meta property="og:url" content="http://etherscan.io/" /> <meta property="og:image" content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" /> <meta property="og:image:url" content="https://etherscan.io/images/brandassets/etherscan-logo-r.jpg" /> <meta property="og:image:alt" content="Visit Etherscan.io" /> <meta name="twitter:card" content="summary" /> <meta name="twitter:title" content=" Ethereum (ETH) Blockchain Explorer" /> <meta property="twitter:description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /> <meta name="twitter:site" content="@etherscan" /> <meta property="twitter:image" content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" />\n<link rel="shortcut icon" href="/images/favicon3.ico" />\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-46998878-6"></script>\n<script>\r\n      window.dataLayer = window.dataLayer || [];\r\n      function gtag(){dataLayer.push(arguments);}\r\n      gtag(\'js\', new Date());\r\n      gtag(\'config\', \'UA-46998878-6\', { \'anonymize_ip\': true });\r\n    </script>\n<script>\r\n        //Search box text ad\r\n        var availableAd = [];\r\n        var gotAd = [];\r\n\r\n        \r\n        availableAd = ["<a class=\'ether-search media rounded p-2\' target=\'_blank\' href=\'https://goto.etherscan.com/rd/3WQS818IUMQ11TPGSCV2F3S48\' rel=\'nofollow\' title=\'Links to an External Advertiser site\'><div class=\'mr-2\'><img class=\'u-xs-avatar mr-2\' src=\'/images/gen/hyperpay_sept_20.png\' alt=\'Ad\'></div><div class=\'media-body\'><h6 class=\'d-flex align-items-center text-size-1 mb-0\'><div class=\'mr-2\'>HyperCard: Crypto Credit Card + No KYC + FREE!</div><span class=\'d-none d-sm-inline-block bg-white-content small text-secondary rounded-sm border px-1 ml-1\'>Sponsored</span><span class=\'d-inline-block d-sm-none bg-white-content small text-secondary rounded-sm border px-1 ml-1\'>Ad</span></h6></div></a>", "<a class=\'ether-search media rounded p-2\' target=\'_blank\' href=\'https://goto.etherscan.com/rd/9PYHB8GDQ84JNC8YXBW1AFRKA\' rel=\'nofollow\' title=\'Links to an External Advertiser site\'><div class=\'mr-2\'><img class=\'u-xs-avatar mr-2\' src=\'/images/gen/aax.jpg\' alt=\'AAX.com\'></div><div class=\'media-body\'><h6 class=\'d-flex align-items-center text-size-1 mb-0\'><div class=\'mr-2\'>AAX.com - Time limited Savings Marathon</div><span class=\'d-none d-sm-inline-block bg-white-content small text-secondary rounded-sm border px-1 ml-1\'>Sponsored</span><span class=\'d-inline-block d-sm-none bg-white-content small text-secondary rounded-sm border px-1 ml-1\'>Ad</span></h6></div></a>"];\r\n        gotAd = [ "ShowAds\t\t\t\t\t" ];\r\n        \r\n    </script>\n<link rel="stylesheet" href="/assets/vendor/font-awesome/css/fontawesome-all.min.css?v=22.9.3.0">\n<link rel="stylesheet" href="/as ...

# %% [markdown]
# Improved GET request.

# %%
import urllib.request

page = urllib.request.urlopen(url).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-db14ee4e18b6> in <module>
#       1 import urllib.request
#       2
# ----> 3 page = urllib.request.urlopen(url).read()
#
# c:\Users\x\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\Users\x\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# c:\Users\x\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# c:\Users\x\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# c:\Users\x\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# c:\Users\x\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Improved GET request with custom headers.

# %%
from urllib.request import Request, urlopen

req = Request(url, headers = hdr)
page = urlopen(req)

# %% [markdown]
# Make soup.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head><title>
# 	 Ethereum (ETH) Blockchain Explorer
# </title><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><meta content="etherscan.io" name="author"/><meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" name="Description"/><meta content="ethereum, explorer, ether, search, blockchain, crypto, currency" name="keywords"/><meta content="telephone=no" name="format-detection"/>
# <meta content=" Ethereum (ETH) Blockchain Explorer" property="og:title"/> <meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" property="og:description"/> <meta content="website" property="og:type"/> <meta content="Ethereum (ETH) Blockchain Explorer" property="og:site_name"/> <meta content="http://etherscan.io/" property="og:url"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="og:image"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-r.jpg" property="og:image:url"/> <meta content="Visit Etherscan.io" property="og:image:alt"/> <meta content="summary" name="twitter:card"/> <meta content=" Ethereum (ETH) Blockchain Explorer" name="twitter:title"/> <meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" property="twitter:description"/> <meta content="@etherscan" name="twitter:site"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="twitter:image"/>
# <link href="/images/favicon3.ico" rel="shortcut icon"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-46998878-6"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-46998878-6', { 'anonymize_ip': true });
#     </script>
# <script>
#         //Search box text ad
#         var availableAd = [];
#         var gotAd = [];
#
#
#         availableAd = ["<a class='ether-search media rounded p-2' target='_blank' href='https://goto.etherscan.com/rd/3WQS818IUMQ11TPGSCV2F3S48' rel='nofollow' title='Links to an External Advertiser site'><div class='mr-2'><img class='u-xs-avatar mr-2' src='/images/gen/hyperpay_sept_20.png' alt='Ad'></div><div class='media-body'><h6 class='d-flex align-items-center text-size-1 mb-0'><div class='mr-2'>HyperCard: Crypto Credit Card + No KYC + FREE!</div><span class='d-none d-sm-inline-block bg-white-content small text-secondary rounded-sm border px-1 ml-1'>Sponsored</span><span class='d-inline-block d-sm-none bg-white-content small text-secondary rounded-sm border px-1 ml-1'>Ad</span></h6></div></a>", "<a class='ether-search media rounded p-2' target='_blank' href='https://goto.etherscan.com/rd/9PYHB8GDQ84JNC8YXBW1AFRKA' rel='nofollow' title='Links to an External Advertiser site'><div class='mr-2'><img class='u-xs-avatar mr-2' src='/images/gen/aax.jpg' alt='AAX.com'></div><div class='media-body'><h6 class='d-flex align-items-center text-size-1 mb-0'><div class='mr-2'>AAX.com - Time limited Savings Marathon</div><span class='d-none d-sm-inline-block bg-white-content small text-secondary rounded-sm border px-1 ml-1'>Sponsored</span><span class='d-inline-block d-sm-none bg-white-content small text-secondary rounded-sm border px-1 ml-1'>Ad</span></h6></div></a>"];
#         gotAd = [ "ShowAds					" ];
#
#     </script>
# <link href="/assets/vendor/font-awesome/css/fontawesome-all.min.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/vendor/animate.css/animate.min.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/vendor/hs-megamenu/src/hs.megamenu.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/vendor/malihu-custom-scrollbar-plugin/jquery.mCustomScrollbar.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/vendor/select2/dist/css/select2.min.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/css/theme.min.css?v=22.9.3.0" rel="stylesheet"/>
# <link href="/assets/css/custom.css?v=22.9.3.0" rel="stylesheet"/>
# <script src="/assets/vendor/jquery/dist/jquery.min.js?v=22.9.3.0"></script>
# <script src="/jss/blockies.js?v=22.9.3.0" type="text/javascript"></script>
# <style>
#         .ui-autocomplete {
#             position: absolute;
#             top: 0;
#             left: 0;
#             cursor: default
#         }
#         .ui-state-active {
#             border-color: #e7eaf3;
#             background: #f8fafd;
#         }
#         body.dark-mode .ui-state-active {
#           background-color: #132a47;
#           border-color: #18365b;
#         }
#
#         .autolink-safari a{
#             pointer-events: none !important;
#             text-decoration:none !important;
#             color:inherit !important;
#         }
#     </style>
# <style> .dywfnkxzhag { -ms-flex-pack: center; justify-content: center; } .abdkslpzhv8 { border-top: 1px solid #e7eaf3 !important; } body.dark-mode .abdkslpzhv8 { border-color: #18365b !important; } @media (min-width: 992px) { .bzhtbyym5s7 { display: block !important; } } @media (min-width: 992px) { .cqetwq6e9yi { display: inline-block !important; } }  </style>
# <style type="text/css">#div-advert {line-height: 1.7}@media (max-width: 667px) {#div-advert {min-height: 62px;}}@media (max-width: 767px) {#div-advert {padding-bottom: 20px;}}</style>
# <style>
#         .wrapper {
#             background-color: #fff !important;
#         }
#         .ui-autocomplete {
#             z-index: 1;
#         }
#     </style>
# </head>
# <body id="body">
# <div class="wrapper">
# <header class="u-header" id="header">
# <div class="u-header__section py-1">
# <div class="container" id="logoAndNav">
# <nav class="js-mega-menu navbar navbar-expand-md u-header__navbar u-header__navbar--no-space">
# <div class="w-lg-auto">
# <a aria-label="Etherscan" class="navbar-brand pt-md-0" href="/" target="_parent">
# <img alt="Etherscan Logo" id="logo-header" src="/assets/svg/logos/logo-etherscan.svg?v=0.0.2" width="160"/>
# </a>
# </div>
# <div>
# <button aria-controls="navBar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler btn u-hamburger" data-target="#navBar" data-toggle="collapse" type="button">
# <span class="u-hamburger__box" id="hamburgerTrigger">
# <span class="u-hamburger__inner"></span>
# </span>
# </button>
# </div>
# <div class="d-flex flex-column w-100">
# <div class="collapse navbar-collapse u-header__navbar-collapse order-md-2" id="navBar">
# <ul class="navbar-nav u-header__navbar-nav px-2 px-md-0">
# <li class="nav-item u-header__nav-item active" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover" id="LI_default">
# <a aria-expanded="false" aria-haspopup="true" aria-labelledby="pagesSubMenu" class="nav-link u-header__nav-link" href="/">Home</a>
# </li>
# <li class="nav-item hs-has-sub-menu u-header__nav-item" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover" id="LI_blockchain">
# <a aria-expanded="false" aria-haspopup="true" aria-labelledby="pagesSubMenu" class="nav-link u-header__nav-link u-header__nav-link-toggle" href="javascript:;" id="blockchainMegaMenu">Blockchain</a>
# <ul aria-labelledby="blockchainMegaMenu" class="hs-sub-menu u-header__sub-menu u-header__sub-menu--spacer" id="blockchainSubMenu" style="min-width: 230px;">
# <li id="LI12"><a class="nav-link u-header__sub-menu-nav-link" href="/txs">View Txns</a></li>
# <li id="LI16"><a class="nav-link u-header__sub-menu-nav-link" href="/txsPending">View Pending Txns</a></li>
# <li id="LI14"><a class="nav-link u-header__sub-menu-nav-link" href="/txsInternal">View Contract Internal Txns</a></li>
# <li class="dropdown-divider"></li>
# <li id="LI_blocks">
# <a aria-controls="navSubBlocks" aria-expanded="false" aria-haspopup="true" class="nav-link u-header__sub-menu-nav-link" href="/blocks" id="navBlocks">View Blocks</a></li>
# <li id="LI_blocks2">
# <a class="nav-link u-header__sub-menu-nav-link" href="/blocks_forked">Forked Blocks (Reorgs)</a>
# </li>
# <li id="LI8"><a class="nav-link u-header__sub-menu-nav-link" href="/uncles">View Uncles</a></li>
# <li class="divider"></li>
# <li class="dropdown-divider"></li>
# <li id="LI_accountall"><a class="nav-link u-header__sub-menu-nav-link" href="/accounts">Top Accounts</a></li>
# <li id="LI_contract_verified"><a class="nav-link u-header__sub-menu-nav-link" href="/contractsVerified">Verified Contracts</a></li>
# </ul>
# </li>
# <li class="nav-item hs-has-sub-menu u-header__nav-item" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover" id="LI_tokens">
# <a aria-expanded="false" aria-haspopup="true" aria-labelledby="tokensSubMenu" class="nav-link u-header__nav-link u-header__nav-link-toggle" href="javascript:;" id="tokensMegaMenu">Tokens</a>
# <ul aria-labelledby="tokensMegaMenu" class="hs-sub-menu u-header__sub-menu u-header__sub-menu--spacer" id="tokensSubMenu" style="min-width: 250px;">
# <li id="LI21"><a class="nav-link u-header__sub-menu-nav-link" href="/tokens">ERC20 Top Tokens</a></li>
# <li id="LI1"><a class="nav-link u-header__sub-menu-nav-link" href="/tokentxns">View ERC20 Transfers</a></li>
# <li class="dropdown-divider"></li>
# <li id="LI42"><a class="nav-link u-header__sub-menu-nav-link" href="/tokens-nft">ERC721 Top Tokens</a></li>
# <li id="LI40"><a class="nav-link u-header__sub-menu-nav-link" href="/tokentxns-nft">View ERC721 Transfers</a></li>
# <li class="dropdown-divider"></li>
# <li id="LI30"><a class="nav-link u-header__sub-menu-nav-link" href="/tokens-nft1155">ERC1155 Top Tokens</a></li>
# <li id="LI33"><a class="nav-link u-header__sub-menu-nav-link" href="/tokentxns-nft1155">View ERC1155 Transfers <sup><span class="badge badge-success font-size-default ml-1"> New</span></sup></a></li>
# </ul>
# </li>
# <li class="nav-item hs-has-sub-menu u-header__nav-item" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover" id="LI_resources">
# <a aria-expanded="false" aria-haspopup="true" aria-labelledby="resourcesSubMenu" class="nav-link u-header__nav-link u-header__nav-link-toggle" href="javascript:;" id="resourcesMegaMenu">Resources</a>
# <ul aria-labelledby="resourcesMegaMenu" class="hs-sub-menu u-header__sub-menu u-header__sub-menu--spacer" id="resourcesSubMenu" style="min-width: 230px;">
# <li id="LI_charts2"><a class="nav-link u-header__sub-menu-nav-link" href="/charts">Charts &amp; Stats</a></li>
# <li id="LI_topstat"><a class="nav-link u-header__sub-menu-nav-link" href="/topstat">Top Statistics</a></li>
# <li id="LI39"><a class="nav-link u-header__sub-menu-nav-link" href="/apis">Developer APIs</a></li>
# <li class="dropdown-divider"></li>
# <li id="LI43"><a class="nav-link u-header__sub-menu-nav-link" href="/directory">Ethereum Directory</a></li>
# </ul>
# </li>
# <li class="nav-item hs-has-mega-menu u-header__nav-item" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover" data-position="left" id="LI_services2">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link u-header__nav-link u-header__nav-link-toggle" href="javascript:;" id="moreMegaMenu">More</a>
# <div aria-labelledby="moreMegaMenu" class="hs-mega-menu w-100 u-header__sub-menu">
# <div class="row u-header__mega-menu-wrapper">
# <div class="col-sm-6 col-md-4 col-lg mb-4 mb-lg-0">
# <span class="u-header__sub-menu-title">Developers</span>
# <ul class="u-header__sub-menu-nav-group mb-3">
# <li id="LI6"><a class="nav-link u-header__sub-menu-nav-link" href="https://docs.etherscan.io/" target="_blank"><i class="fa fa-angle-right small mr-1"></i>API Documentation</a></li>
# <li id="LI17"><a class="nav-link u-header__sub-menu-nav-link" href="/verifyContract"><i class="fa fa-angle-right small mr-1"></i>Verify Contract</a></li>
# <li id="LI24"><a class="nav-link u-header__sub-menu-nav-link" href="/opcode-tool"><i class="fa fa-angle-right small mr-1"></i>Byte to Opcode</a></li>
# <li id="LI10"><a class="nav-link u-header__sub-menu-nav-link" href="/pushTx"><i class="fa fa-angle-right small mr-1"></i>Broadcast TXN</a></li>
# <li id="LI27"><a class="nav-link u-header__sub-menu-nav-link" href="/vyper"><i class="fa fa-angle-right small mr-1"></i>Vyper Online Compiler</a></li>
# <li id="LI53"><a class="nav-link u-header__sub-menu-nav-link" href="/searchcontract"><i class="fa fa-angle-right small mr-1"></i>Smart Contract Search<sup><span class="badge badge-success font-size-default ml-1">New</span></sup></a></li>
# <li id="LI54"><a class="nav-link u-header__sub-menu-nav-link" href="/contractdiffchecker"><i class="fa fa-angle-right small mr-1"></i>Contract Diff Checker<sup><span class="badge badge-success font-size-default ml-1">New</span></sup></a></li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-4 col-lg mb-4 mb-lg-0">
# <span class="u-header__sub-menu-title">DeFi</span>
# <ul class="u-header__sub-menu-nav-group mb-3">
# <li id="LI48"><a class="nav-link u-header__sub-menu-nav-link" href="/dex#transactions"><i class="fa fa-angle-right small mr-1"></i>DEX Transactions</a></li>
# <li id="LI4"><a class="nav-link u-header__sub-menu-nav-link" href="/dex#tradingpairs"><i class="fa fa-angle-right small mr-1"></i>DEX Trading Pairs <sup><span class="badge badge-secondary font-size-default ml-1"> Beta</span></sup></a></li>
# <li id="LI13"><a class="nav-link u-header__sub-menu-nav-link" href="/nfttracker"><i class="fa fa-angle-right small mr-1"></i>NFT Tracker<sup><span class="badge badge-secondary font-size-default ml-1">Beta</span></sup></a></li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-4 col-lg mb-4 mb-lg-0">
# <span class="u-header__sub-menu-title">Explore</span>
# <ul class="u-header__sub-menu-nav-group mb-3">
# <li id="LI19"><a class="nav-link u-header__sub-menu-nav-link" href="/gastracker"><i class="fa fa-angle-right small mr-1"></i>Gas Tracker</a></li>
# <li id="LI46"><a class="nav-link u-header__sub-menu-nav-link" href="/nodetracker"><i class="fa fa-angle-right small mr-1"></i>Node Tracker</a></li>
# <li id="LI26"><a class="nav-link u-header__sub-menu-nav-link" href="/enslookup"><i class="fa fa-angle-right small mr-1"></i>Ethereum Name Lookup</a></li>
# <li id="LI25"><a class="nav-link u-header__sub-menu-nav-link" href="/connect"><i class="fa fa-angle-right small mr-1"></i>Etherscan Connect</a></li>
# <li id="LI22"><a class="nav-link u-header__sub-menu-nav-link" href="/txsBeaconDeposit"><i class="fa fa-angle-right small mr-1"></i>Eth2 Beacon Chain Deposits</a></li>
# <li id="LI52"><a class="nav-link u-header__sub-menu-nav-link" href="/idm"><i class="fa fa-angle-right small mr-1"></i>IDM<sup><span class="badge badge-secondary font-size-default ml-1"> Beta</span></sup></a></li>
# </ul>
# </div>
# <div class="col-sm-6 col-md-4 col-lg mb-4 mb-lg-0">
# <span class="u-header__sub-menu-title">Tools</span>
# <ul class="u-header__sub-menu-nav-group mb-3">
# <li id="LI41"><a class="nav-link u-header__sub-menu-nav-link" href="/labelcloud"><i class="fa fa-angle-right small mr-1"></i>Label Word Cloud</a></li>
# <li id="LI29"><a class="nav-link u-header__sub-menu-nav-link" href="/verifiedSignatures"><i class="fa fa-angle-right small mr-1"></i>Verified Signature</a></li>
# <li id="LI49"><a class="nav-link u-header__sub-menu-nav-link" href="/tokenapprovalchecker"><i class="fa fa-angle-right small mr-1"></i>Token Approvals <sup><span class="badge badge-secondary font-size-default ml-1"> Beta</span></sup></a></li>
# <li id="LI50"><a class="nav-link u-header__sub-menu-nav-link" href="/unitconverter"><i class="fa fa-angle-right small mr-1"></i>Unit Converter </a></li>
# <li><a class="nav-link u-header__sub-menu-nav-link" href="https://chat.blockscan.com"><i class="fa fa-angle-right small mr-1"></i>Blockscan Chat <sup><span class="badge badge-secondary font-size-default ml-1"> Beta</span></sup></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="u-header__nav-separator"></li>
# <li class="nav-item my-2 my-md-0">
# <a class="u-header__nav-link" href="/login">
# <i class="fa fa-user-circle mr-1"></i>Sign In
# </a>
# </li>
# <li class="u-header__nav-separator"></li>
# <li class="nav-item hs-has-sub-menu u-header__nav-item my-md-n1" data-animation-in="slideInUp" data-animation-out="fadeOut" data-event="hover">
# <a aria-expanded="false" aria-haspopup="true" aria-labelledby="explorersDropdown" class="nav-link u-header__nav-link u-header__nav-link-toggle u-header__nav-link-toggle--mobile pr-0" href="javascript:;" id="explorersWithDropdown">
# <span class="btn btn-sm btn-icon btn-soft-primary cursor-pointer d-none d-md-inline-block">
# <img alt="Ethereum Logo" class="u-xs-avatar btn-icon__inner" src="/images/ethereum-icon.png"/>
# </span>
# <span class="d-inline-block d-md-none">Explorers</span>
# </a>
# <ul aria-labelledby="explorersWithDropdown" class="hs-sub-menu u-header__sub-menu u-header__sub-menu--spacer dropdown-menu-md-right animated fadeOut" id="explorersDropdown" style="min-width: 200px; display: none;">
# <li class="active active" id="LI_Mainnet"><a class="nav-link u-header__sub-menu-nav-link" href="https://etherscan.io">Ethereum Mainnet</a></li>
# <li id="LI_Mainnet_CN"><a class="nav-link u-header__sub-menu-nav-link" href="https://cn.etherscan.com/?lang=zh-CN">Ethereum Mainnet <span class="badge badge-info ml-1"> CN</span></a></li>
# <li class="dropdown-divider mb-3"></li>
# <li id="LI28"><a class="nav-link u-header__sub-menu-nav-link" href="https://ropsten.etherscan.io" target="_blank">Ropsten Testnet</a></li>
# <li id="LI31"><a class="nav-link u-header__sub-menu-nav-link" href="https://kovan.etherscan.io" target="_blank">Kovan Testnet</a></li>
# <li id="LI32"><a class="nav-link u-header__sub-menu-nav-link" href="https://rinkeby.etherscan.io" target="_blank">Rinkeby Testnet</a></li>
# <li id="LI58"><a class="nav-link u-header__sub-menu-nav-link" href="https://goerli.etherscan.io" target="_blank">Goerli Testnet</a></li>
# <li id="LI9"><a class="nav-link u-header__sub-menu-nav-link" href="https://sepolia.etherscan.io" target="_blank">Sepolia Testnet</a></li>
# <li class="dropdown-divider"></li>
# <li id="LI2"><a class="nav-link u-header__sub-menu-nav-link" href="https://beaconscan.com" target="_blank" title="Ethereum 2.0 Beacon Chain Testnet Explorer">BeaconScan <span class="badge badge-secondary font-size-default ml-1"> Eth2</span></a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </header>
# <main id="content" role="main">
# <input id="hdnAgeText" name="hdnAgeText" type="hidden" value="Age"/>
# <input id="hdnDateTimeText" name="hdnDateTimeText" type="hidden" value="Date Time (UTC)"/>
# <input id="hdnAgeTitle" name="hdnAgeTitle" type="hidden" value="Click to show Age Format"/>
# <input id="hdnDateTimeTitle" name="hdnDateTimeTitle" type="hidden" value="Click to show Datetime Format"/>
# <input id="hdnTxnText" name="hdnTxnText" type="hidden" value="Txn Fee"/>
# <input id="hdnGasPriceText" name="hdnGasPriceText" type="hidden" value="Gas Price"/>
# <input id="hdnTxnFeeTitle" name="hdnTxnFeeTitle" type="hidden" value="(Gas Price * Gas Used by Txns) in Ether"/>
# <input id="hdnGasPriceTitle" name="hdnGasPriceTitle" type="hidden" value="Gas Price in Gwei"/>
# <section class="bg-dark" style="background-image: url(/images/svg/components/abstract-shapes-20.svg?v=1);">
# <div class="container space-top-2 space-bottom-3">
# <div class="row justify-content-between align-items-center mb-4">
# <div class="col-md-12 col-lg-7">
# <div class="pr-lg-4 pr-xll-5">
# <h1 class="h4 text-white mb-3">
# The Ethereum Blockchain Explorer
# </h1>
# <form action="/search" class="mb-3" method="GET">
# <div class="input-group input-group-shadow">
# <div class="input-group-prepend d-none d-md-block">
# <select class="custom-select custom-arrow-select input-group-text font-size-base filterby text-left" name="f">
# <option selected="" value="0">All Filters</option>
# <option value="1">Addresses</option>
# <option value="2">Tokens</option>
# <option value="3">Name Tags</option>
# <option value="4">Labels</option>
# <option value="5">Websites</option>
# </select>
# </div>
# <input aria-describedby="button-header-search" autocomplete="off" class="form-control searchautocomplete" id="txtSearchInput" maxlength="68" name="q" onkeyup="handleSearchText(this);" placeholder="Search by Address / Txn Hash / Block / Token / Ens" spellcheck="false" type="text"/>
# <input id="hdnSearchText" type="hidden" value=""/>
# <input id="hdnSearchLabel" type="hidden" value=""/>
# <input id="hdnIsTestNet" type="hidden" value="False"/>
# <div class="input-group-append">
# <button class="btn btn-primary" type="submit">
# <i class="fa fa-search"></i>
# </button>
# </div>
# </div>
# </form>
# <p class="text-white-70 mb-0" style="min-height:22px">
# <ins data-revive-id="6452186c83cd256052c3c100f524ed97" data-revive-zoneid="6"></ins>
# <script async="" src="//kta.etherscan.com/www/d/asyncjses.php"></script>
# </p>
# </div>
# </div>
# <div class="col-12 col-lg-5">
# <div class="d-none bzhtbyym5s7 text-center pl-lg-4 pl-xll-5">
# <a class="d-inline-block d-sm-none position-relative text-dark" href="https://goto.etherscan.com/rd/HSVVYHJ96U7SKU1UHSBS6MIJV" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="left: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_321x101.png"/></a>
# <a class="d-none d-sm-inline-block d-lg-none position-relative text-dark" href="https://goto.etherscan.com/rd/NNWUUTJ7JXBHZMRS3AGIEETEF" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="left: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_730x90.png"/></a>
# <a class="d-none d-lg-inline-block-alt position-relative text-dark" href="https://goto.etherscan.com/rd/S9EIHWMENTEQB94NM5APUAQ5C" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="right: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_321x101.png"/></a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="container space-bottom-1 mt-n5">
# <div class="card mb-4" id="ContentPlaceHolder1_mainboxes">
# <div class="card-body p-4">
# <div class="row mx-gutters-md-1 align-items-center">
# <div class="col-md-6 col-lg-4">
# <div class="media align-items-center">
# <figure class="u-sm-avatar mr-2">
# <div class="u-xs-avatar mx-auto">
# <img alt="Ethereum Logo" src="/images/svg/brands/ethereum-1.svg"/>
# </div>
# </figure>
# <div class="media-body">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Ether Price</h2>
# <a class="text-size-1 text-link" data-placement="bottom" data-toggle="tooltip" href="/chart/etherprice" rel="tooltip" title="View Historical Ether Price">$1,392.48<span class="text-secondary"> @ 0.06867 BTC</span><span class="text-success small"> (+7.35%)</span></a>
# </div>
# </div>
# <hr class="hr-space-lg"/>
# <div class="media align-items-center">
# <figure class="u-sm-avatar mr-2">
# <img alt="SVG" src="/images/svg/icons/icon-8.svg?v=1.3"/>
# </figure>
# <div class="media-body">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Market Cap
# </h2>
# <a class="text-size-1 text-link" data-placement="top" data-title="View More" data-toggle="tooltip" href="/stat/supply">
# $167,834,213,918.00
# </a>
# </div>
# </div>
# <hr class="d-block d-md-none hr-space-lg"/>
# </div>
# <div class="col-md-6 col-lg-4 u-ver-divider u-ver-divider--left u-ver-divider--none-md">
# <div class="media align-items-center">
# <figure class="u-sm-avatar mr-2">
# <img alt="Transaction" src="/images/svg/icons/icon-2-1.svg?v=1.3"/>
# </figure>
# <div class="media-body">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Transactions</h2>
# <a class="text-size-1 text-link" data-html="true" data-placement="left" data-toggle="tooltip" href="/txs" rel="tooltip" title="Total Transactions Counter&lt;br&gt;(Update every 5 mins)">1,725.22 M</a><span class="text-secondary small" data-placement="bottom" data-toggle="tooltip" rel="tooltip" title="Transactions per Second"> (14.5 TPS)</span>
# </div>
# <div class="text-right" title="GasTracker Estimate for Average Gas">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Med Gas Price</h2>
# <a class="text-size-1 text-link" data-html="true" data-toggle="tooltip" href="/gastracker" title="Base Fee: 9 Gwei&lt;br&gt;Priority Fee: 2 Gwei">11 Gwei <span class="text-secondary small">($0.32)</span></a>
# </div>
# </div>
# <hr class="hr-space-lg"/>
# <div class="media align-items-center">
# <figure class="u-sm-avatar mr-2" data-placement="top" data-toggle="tooltip" title="Last Safe and Finalized Blocks">
# <img alt="SVG" src="/images/svg/icons/icon-51.svg"/>
# </figure>
# <div class="media-body">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Last Finalized Block</h2>
# <div class="text-size-1"><span data-placement="bottom" data-toggle="tooltip" rel="tooltip" stake.="" title="This block is finalized and cannot be reverted without slashing at least 1/3 of all validators">15624454</span></div>
# </div>
# <div class="text-right">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Last Safe Block</h2>
# <div class="text-size-1"><span data-placement="bottom" data-toggle="tooltip" rel="tooltip" title="This block is safe and is unlikely to be reverted.">15624486</span></div>
# </div>
# </div>
# <hr class="d-block d-md-none hr-space-lg"/>
# </div>
# <div class="col-md-12 col-lg-4 u-ver-divider u-ver-divider--left u-ver-divider--none-lg">
# <hr class="d-none d-md-block d-lg-none my-4"/>
# <div class="d-flex justify-content-between align-items-center">
# <h2 class="font-size-1 text-uppercase text-secondary mb-0">Ethereum Transaction History in 14 days</h2>
# <div class="position-relative float-right z-index-2">
# <a aria-controls="customcharts" aria-expanded="false" aria-haspopup="true" class="btn btn-xs btn-icon btn-soft-secondary" data-unfold-animation-in="slideInUp" data-unfold-animation-out="fadeOut" data-unfold-delay="300" data-unfold-duration="300" data-unfold-event="click" data-unfold-hide-on-scroll="true" data-unfold-target="#customcharts" data-unfold-type="css-animation" href="javascript:;" id="customchartsinvoker" role="button">
# <i class="fa fa-ellipsis-v btn-icon__inner"></i>
# </a>
# <div aria-labelledby="customchartsinvoker" class="dropdown-menu dropdown-menu-right dropdown-unfold" id="customcharts">
# <a class="dropdown-item" href="/chart/tx">View Detailed Chart</a>
# </div>
# </div>
# </div>
# <div class="w-100 pt-2" id="container-1" style="height: 106px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="d-block d-lg-none text-center pl-lg-4 pl-xll-5 mb-4">
# <a class="d-inline-block d-sm-none position-relative text-dark" href="https://goto.etherscan.com/rd/HSVVYHJ96U7SKU1UHSBS6MIJV" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="left: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_321x101.png"/></a>
# <a class="d-none d-sm-inline-block d-lg-none position-relative text-dark" href="https://goto.etherscan.com/rd/NNWUUTJ7JXBHZMRS3AGIEETEF" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="left: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_730x90.png"/></a>
# <a class="d-none d-lg-inline-block-alt position-relative text-dark" href="https://goto.etherscan.com/rd/S9EIHWMENTEQB94NM5APUAQ5C" target="_blank">
# <span class="showcase-banner-text bg-white font-size-1 shadow rounded px-1" style="right: 1rem;">Ad</span><img alt="Ads" class="img-fluid rounded" src="/images/gen/aax_057-059_321x101.png"/></a>
# </div>
# <div class="row mb-5">
# <div class="col-lg-6 mb-4 mb-lg-0">
# <div class="card h-100">
# <div class="card-header">
# <h2 class="card-header-title">Latest Blocks</h2>
# </div>
# <div class="js-scrollbar card-body overflow-hidden" style="height: 400px;">
# <div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary"><span class="btn-icon__inner text-dark">Bk</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none">Block</span> <a href="/block/15624544">15624544</a><span class="d-sm-block small text-secondary ml-1 ml-sm-0 text-nowrap"> 8 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-flex justify-content-between"><div class="text-nowrap"><span class="d-block mb-1 mb-sm-0">Fee Recipient <a class="hash-tag text-truncate" href="/address/0x4675c7e5baafbffbca748158becba61ef3b0a263">Fee Recipient: 0x467...263</a></span><a data-toggle="tooltip" href="/txs?block=15624544" title="Transactions in this Block">71 txns </a> <span class="small text-secondary">in 12 secs</span><span class="d-inline-block d-sm-none"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>01976 Eth</span></span></div><div class="d-none d-sm-block"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>01976 Eth</span></div></div></div></div><hr class="hr-space"/><div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary"><span class="btn-icon__inner text-dark">Bk</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none">Block</span> <a href="/block/15624543">15624543</a><span class="d-sm-block small text-secondary ml-1 ml-sm-0 text-nowrap"> 20 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-flex justify-content-between"><div class="text-nowrap"><span class="d-block mb-1 mb-sm-0">Fee Recipient <a class="hash-tag text-truncate" href="/address/0x388c818ca8b9251b393131c08a736a67ccb19297">Lido: Execution Layer Rewards Vault</a></span><a data-toggle="tooltip" href="/txs?block=15624543" title="Transactions in this Block">176 txns </a> <span class="small text-secondary">in 12 secs</span><span class="d-inline-block d-sm-none"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>04037 Eth</span></span></div><div class="d-none d-sm-block"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>04037 Eth</span></div></div></div></div><hr class="hr-space"/><div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary"><span class="btn-icon__inner text-dark">Bk</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none">Block</span> <a href="/block/15624542">15624542</a><span class="d-sm-block small text-secondary ml-1 ml-sm-0 text-nowrap"> 32 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-flex justify-content-between"><div class="text-nowrap"><span class="d-block mb-1 mb-sm-0">Fee Recipient <a class="hash-tag text-truncate" href="/address/0xe688b84b23f322a994a53dbf8e15fa82cdb71127">Fee Recipient: 0xe68...127</a></span><a data-toggle="tooltip" href="/txs?block=15624542" title="Transactions in this Block">154 txns </a> <span class="small text-secondary">in 12 secs</span><span class="d-inline-block d-sm-none"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>1201 Eth</span></span></div><div class="d-none d-sm-block"><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Block Reward">0<b>.</b>1201 Eth</span></div></div></div> ...
# </div>
# <div class="card-footer">
# <a class="btn btn-xs btn-block btn-soft-primary" href="/blocks">View all blocks</a>
# </div>
# </div>
# </div>
# <div class="col-lg-6">
# <div class="card h-100">
# <div class="card-header">
# <h2 class="card-header-title">Latest Transactions</h2>
# </div>
# <div class="js-scrollbar card-body overflow-hidden" style="height: 400px;">
# <div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary rounded-circle"><span class="btn-icon__inner text-dark">Tx</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none mr-1">TX#</span><a class="hash-tag hash-tag--xs hash-tag-xs-down--md text-truncate" href="/tx/0x4997f537cd3d4a01389cf97ac7fa57eadacfa58d339e2c89991b4e50fb9f6e74">0x4997f537cd3d4a01389cf97ac7fa57eadacfa58d339e2c89991b4e50fb9f6e74</a><span class="d-none d-sm-block small text-secondary">8 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-sm-flex justify-content-between"><div class="text-nowrap mr-4 mb-1 mb-sm-0"><span>From <a class="hash-tag text-truncate" href="/address/0x6887246668a3b87f54deb3b94ba47a6f63f32985">0x6887246668a3b87f54deb3b94ba47a6f63f32985</a></span><span class="d-sm-block">To <a class="hash-tag text-truncate" href="/address/0x5e4e65926ba27467555eb562121fac00d24e9dd2">0x5e4e65926ba27467555eb562121fac00d24e9dd2</a></span></div><div><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Amount">0 Eth</span></div></div></div></div><hr class="hr-space"/><div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary rounded-circle"><span class="btn-icon__inner text-dark">Tx</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none mr-1">TX#</span><a class="hash-tag hash-tag--xs hash-tag-xs-down--md text-truncate" href="/tx/0x862413ac09bbb887b751c55c7c4575a2842c165e648d7f1eaaf4e11c2f7b3829">0x862413ac09bbb887b751c55c7c4575a2842c165e648d7f1eaaf4e11c2f7b3829</a><span class="d-none d-sm-block small text-secondary">8 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-sm-flex justify-content-between"><div class="text-nowrap mr-4 mb-1 mb-sm-0"><span>From <a class="hash-tag text-truncate" href="/address/0x18163c01ccca2c20ab922c22f09db2b31c3fb74a">0x18163c01ccca2c20ab922c22f09db2b31c3fb74a</a></span><span class="d-sm-block">To <a class="hash-tag text-truncate" href="/address/0xdac17f958d2ee523a2206206994597c13d831ec7">0xdac17f958d2ee523a2206206994597c13d831ec7</a></span></div><div><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Amount">0 Eth</span></div></div></div></div><hr class="hr-space"/><div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span class="btn btn-icon btn-soft-secondary rounded-circle"><span class="btn-icon__inner text-dark">Tx</span></span></div><div class="media-body"><span class="d-inline-block d-sm-none mr-1">TX#</span><a class="hash-tag hash-tag--xs hash-tag-xs-down--md text-truncate" href="/tx/0x18243f24ec007d8858a8ab9c9781829b9437e42d86745b21380f8fedf1f6b685">0x18243f24ec007d8858a8ab9c9781829b9437e42d86745b21380f8fedf1f6b685</a><span class="d-none d-sm-block small text-secondary">8 secs ago</span></div></div></div><div class="col-sm-8"><div class="d-sm-flex justify-content-between"><div class="text-nowrap mr-4 mb-1 mb-sm-0"><span>From <a class="hash-tag text-truncate" href="/address/0x327408211629aa40c8d83b990ce7a7e718d41aa6">0x327408211629aa40c8d83b990ce7a7e718d41aa6</a></span><span class="d-sm-block">To <a class="hash-tag text-truncate" href="/address/0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45">0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45</a></span></div><div><span class="u-label u-label--xs u-label--badge-in u-label--secondary text-center text-nowrap" data-toggle="tooltip" title="Amount">19<b>.</b>49467 Eth</span></div></div></div></div><hr class="hr-space"/><div class="row"><div class="col-sm-4"><div class="media align-items-sm-center mr-4 mb-1 mb-sm-0"><div class="d-none d-sm-flex mr-2"><span c ...
# </div>
# <div class="card-footer">
# <a class="btn btn-xs btn-block btn-soft-primary" href="/txs">View all transactions</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div id="push"></div>
# <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="emailSubscribeModalBox" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-sm" role="document">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close close-md" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <div class="text-center py-5-alt px-4">
# <div id="emailSubscribeModalBoxText"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="bg-dark py-4" style="background-image: url(/images/svg/components/abstract-shapes-20.svg?v=1);">
# <div class="container">
# <div class="row justify-content-md-between font-size-1 py-2" style="background: url(/images/world-map-white.png) no-repeat 0 30%;">
# <div class="col-lg-3 mb-4 mb-lg-0">
# <div class="d-flex h-100 flex-column">
# <div class="d-flex align-items-center mb-4">
# <img alt="Ethereum Logo" src="/images/svg/brands/ethereum.svg?v=1.3" width="20"/>
# <span class="h4 text-white mb-0 ml-3">Powered by Ethereum</span>
# </div>
# <p class="text-white">Etherscan is a Block Explorer and Analytics Platform for Ethereum, a decentralized smart contracts platform.</p>
# <div class="d-flex align-items-center">
# <a class="btn btn-xss btn-soft-light mr-2" href="/settings">
# <i class="fa fa-cogs mr-1"></i>Preferences
# </a>
# <button class="btn btn-sm btn-icon btn-soft-light" data-title="Day/Night Mode" data-toggle="tooltip" id="darkModaBtn" type="button">
# <i class="fa fa-moon" id="darkModaBtnIcon"></i></button>
# </div>
# </div>
# </div>
# <div class="col-6 col-md-4 col-lg-2 mb-4 mb-lg-0">
# <h4 class="h6 text-white heading-border">Company</h4>
# <ul class="list-group list-group-sm list-group-transparent list-group-white list-group-flush list-group-borderless mb-0">
# <li><a class="list-group-item" href="/aboutus">About Us</a></li>
# <li><a class="list-group-item" href="/contactus">Contact Us</a></li>
# <li><a class="list-group-item" href="/brandassets">Brand Assets</a></li>
# <li><a class="list-group-item" href="/careers">Careers<sup><span class="badge badge-success font-size-default ml-1"> Join Us</span></sup></a></li>
# <li><a class="list-group-item" href="/terms">Terms of Service</a></li>
# <li><a class="list-group-item" href="/bugbounty">Bug Bounty</a></li>
# </ul>
# </div>
# <div class="col-6 col-md-4 col-lg-2 mb-4 mb-lg-0">
# <h4 class="h6 text-white heading-border">Resources</h4>
# <ul class="list-group list-group-sm list-group-transparent list-group-white list-group-flush list-group-borderless mb-0">
# <li><a class="list-group-item" href="https://docs.etherscan.io/" target="_blank">API Documentation</a></li>
# <li><a class="list-group-item" href="https://info.etherscan.com/" target="_blank">Knowledge Base</a></li>
# <li><a class="list-group-item" href="https://info.etherscan.com/etherscan-newsletters/" target="_blank">Newsletter</a></li>
# <li><a class="list-group-item" href="https://etherscan.freshstatus.io/" rel="nofollow noopener" target="_blank">Network Status</a></li>
# <li><a class="list-group-item" href="/comments">Disqus Comments</a></li>
# </ul>
# </div>
# <div class="col-6 col-md-4 col-lg-2 mb-4 mb-lg-0">
# <h4 class="h6 text-white heading-border">Products &amp; Services</h4>
# <ul class="list-group list-group-sm list-group-transparent list-group-white list-group-flush list-group-borderless mb-0">
# <li><a class="list-group-item" href="/contactusadvertise">Advertise</a></li>
# <li><a class="list-group-item" href="/eaas">Explorer-as-a-Service (EaaS)</a></li>
# <li><a class="list-group-item" href="/apis" title="Developer APIs">Developer APIs</a></li>
# <li><a class="list-group-item" href="https://blockscan.com/" target="_blank" title="Decentralized Web (.ens,.crypto) Search Engine">Blockscan</a></li>
# <li><a class="list-group-item" href="https://beaconscan.com/" target="_blank" title="Beacon Chain Explorer for Ethereum 2.0">BeaconScan</a></li>
# </ul>
# </div>
# </div>
# <hr class="opacity-md"/>
# <div class="row justify-content-between align-items-center font-size-1">
# <div class="col-md-6 mb-2 mb-md-0">
# <p class="mb-0 text-white">Etherscan © 2022 (F1)  |  <a class="text-white-70" href="/address/0x71c7656ec7ab88b098defb751b7401b5f6d8976f">Donate</a> <i class="fas fa-heart text-danger"></i></p>
# </div>
# <div class="col-md-6 text-md-right">
# <ul class="list-inline mb-0">
# <li class="list-inline-item">
# <a class="btn btn-sm btn-icon btn-soft-light btn-pill" data-placement="top" data-toggle="tooltip" href="https://twitter.com/etherscan" rel="nofollow noopener" target="_blank" title="Twitter">
# <i class="fab fa-twitter btn-icon__inner"></i>
# </a>
# </li>
# <li class="list-inline-item">
# <a class="btn btn-sm btn-icon btn-soft-light btn-pill" data-placement="top" data-toggle="tooltip" href="https://www.facebook.com/etherscan/" rel="nofollow noopener" target="_blank" title="Facebook">
# <i class="fab fa-facebook btn-icon__inner"></i>
# </a>
# </li>
# <li class="list-inline-item">
# <a class="btn btn-sm btn-icon btn-soft-light btn-pill" data-placement="top" data-toggle="tooltip" href="https://www.reddit.com/r/etherscan/" rel="nofollow noopener" target="_blank" title="Reddit">
# <i class="fab fa-reddit-alien btn-icon__inner"></i>
# </a>
# </li>
# <li class="list-inline-item">
# <a class="btn btn-sm btn-icon btn-soft-light btn-pill" data-placement="top" data-toggle="tooltip" href="https://medium.com/etherscan-blog" rel="nofollow noopener" target="_blank" title="Medium">
# <i class="fab fa-medium btn-icon__inner"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <div class="fixed-bottom w-md-75 w-xl-60 mx-md-auto mx-3" id="divcookie" style="display: none;">
# <div class="alert alert-light border shadow p-3" role="alert">
# <div class="d-md-flex align-items-center" style="justify-content: center;">
# <span>
# <p class="text-dark mr-3 mb-2 mb-md-0">
# <i class="far fa-cookie-bite text-secondary mr-1"></i>This website <a href="/terms#cookiestatement" target="_blank">uses cookies to improve your experience</a>. By continuing to use this website, you agree to its <a href="/terms" target="_blank">Terms</a> and <a href="/privacyPolicy" target="_blank">Privacy Policy</a>.
# </p>
# </span>
# <div>
# <button aria-label="Close" class="btn btn-sm btn-primary text-nowrap py-1" data-dismiss="alert" id="btnCookie">Got It</button>
# </div>
# </div>
# </div>
# </div>
# <a class="js-go-to u-go-to" data-compensation="#header" data-hide-effect="slideOutDown" data-offset-top="400" data-position='{"bottom": 20, "right": 15 }' data-show-effect="slideInUp" data-type="fixed" href="#">
# <span class="fa fa-arrow-up u-go-to__inner"></span>
# </a>
# <script src="/assets/vendor/jquery-ui/jquery-ui.min.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/jquery-migrate/dist/jquery-migrate.min.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/popper.js/dist/umd/popper.min.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/bootstrap/bootstrap.min.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/hs-megamenu/src/hs.megamenu.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/malihu-custom-scrollbar-plugin/jquery.mCustomScrollbar.concat.min.js?v=22.9.3.0"></script>
# <script src="/assets/vendor/cubeportfolio/js/jquery.cubeportfolio.min.js?v=22.9.3.0"></script>
# <script src="/assets/js/hs.core.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.header.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.unfold.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.malihu-scrollbar.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.focus-state.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.go-to.js?v=22.9.3.0"></script>
# <script src="/assets/js/components/hs.cubeportfolio.js?v=22.9.3.0"></script>
# <script src="/assets/js/custom/combine-js-bottom2.js?v=22.9.3.0"></script>
# <script>
#         $(window).on('load', function () {
#             // initialization of HSMegaMenu component
#             $('.js-mega-menu').HSMegaMenu({
#                 event: 'hover',
#                 pageContainer: $('.container'),
#                 breakpoint: 767.98,
#                 hideTimeOut: 0
#             });
#             myfn_subscribeNewsletter.startFn("#btnSubscribeNewsletter","#signupSrEmail")
#         });
#
#         $(document).on('ready', function () {
#             // initialization of header
#             $.HSCore.components.HSHeader.init($('#header'));
#
#             // initialization of unfold component
#             $.HSCore.components.HSUnfold.init($('[data-unfold-target]'), {
#                 afterOpen: function () {
#                     $(this).find('input[type="search"]').focus();
#                 }
#             });
#
#             // initialization of malihu scrollbar
#             $.HSCore.components.HSMalihuScrollBar.init($('.js-scrollbar'));
#
#             // initialization of focus state
#             $.HSCore.components.HSFocusState.init();
#
#             // initialization of go to
#             $.HSCore.components.HSGoTo.init('.js-go-to');
#
#             // initialization of cubeportfolio
#             //$.HSCore.components.HSCubeportfolio.init('.cbp');
#         });
#     </script>
# <script type="text/javascript">
#         var sid = '976aaaffffd0cb0a6280038f5a5c4cd7';
#         var strGlobal = getCookie("etherscan_switch_age_datetime");
#         var strGlobalFee = sessionStorage.getItem("ShowFee");
#         var cookieconsent = getCookie("etherscan_cookieconsent");
#
#
#         if (cookieconsent !== "True") {
#             document.getElementById("divcookie").style.display = "block";
#         };
#
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var ca = document.cookie.split(';');
#             for (var i = 0; i < ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) === ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) === 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#         $("#btnCookie").click(function () {
#             $("#divcookie").fadeOut("slow", function () {
#                 var d = new Date();
#                 d.setTime(d.getTime() + (1095 * 24 * 60 * 60 * 1000));
#                 var expires = "expires=" + d.toUTCString();
#                 document.cookie = "etherscan_cookieconsent=True" + ";" + expires + ";path=/";;
#             });
#         });
#         function handleSearchText(data) {
#             searchAddress = false;
#             if ($("txtSearchInput").val() == "") {
#                 $("#hdnSearchText").val("");
#                 $("#hdnSearchLabel").val("");
#             }
#         }
#     </script>
# <script src="/assets/highcharts/v/highcharts.js?v=22.9.3.0"></script>
# <script>
#         var lang_miner = "Fee Recipient";
#         var lang_mined_by = "Mined by";
#         var lang_block = "Block";
#         var lang_block_reward = "Block Reward";
#         var lang_sec = "sec";
#         var lang_secs = "secs";
#         var lang_min = "min";
#         var lang_mins = "mins";
#         var lang_from = "From";
#         var lang_to = "To";
#         var lang_amount = "Amount";
#         var lang_tx = "Tx";
#         var lang_bk = "Bk";
#         var lang_ether = "Eth";
#         var lang_txns = "txns";
#         var lang_in_X = "in";
#         var lang_ago = "ago";
#         var lang_secs_ago = "less than 1 sec ago";
#         var lang_sec_ago = "sec ago";
#         var lang_sec_in = "";
#     </script>
# <script type="text/javascript">
#         $(function () {
#             $('#container-1').highcharts({
#                 chart: {
#                     spacingTop: 10,
#                     spacingBottom: 0,
#                     spacingLeft: 0,
#                     spacingRight: 10,
#                 },
#
#                 title: {
#                     text: '',
#                     align: 'left',
#                 },
#
#                 xAxis: {
#                     title: { text: '' },
#                     lineWidth: 0,
#                     minorTickLength: 0,
#                     tickLength: 0,
#                     labels: {
#                         step: 7,
#                     },
#                     categories: [
#                         'Sep 12','Sep 13','Sep 14','Sep 15','Sep 16','Sep 17','Sep 18','Sep 19','Sep 20','Sep 21','Sep 22','Sep 23','Sep 24','Sep 25','Sep 26',
#                     ]
#                 },
#
#                 yAxis: {
#                     labels: {
#                         enabled: true
#                     },
#                     gridLineWidth: 0,
#                     title: {
#                         text: null
#                     }
#                 },
#
#                 legend: {
#                     enabled: false
#                 },
#
#                 credits: {
#                     enabled: false
#                 },
#
#                 tooltip: {
#                     formatter: function () {
#                         return '<span style="font-size:10px">' + this.point.friendlydate + '</span><br><table><tr><td style="padding:0">' +
#                             '<span style="color:' + this.series.color + '">Transactions: </a></span><b>' + this.point.formattedValue + '</b><br>' +
#                             '<br>' + 'Price: ' + this.point.price + ''
#                             '</td></tr></table>';
#                     }
#                 },
#
#                 plotOptions: {
#                     series: {
#                         color: '#1e2022',
#                         enableMouseTracking: true,
#                         lineWidth: 1,
#                         shadow: false,
#                         animation: false,
#                         cursor: 'pointer',
#                         states: {
#                             hover: {
#                                 lineWidth: 1
#                             }
#                         },
#                         marker: {
#                             radius: 0
#                         },
#                         point: {
#                             events: {
#                                 select: function (e) {
#                                     location.href = 'txs?dt=' + this.options.dt;
#                                 }
#                             }
#                         }
#                     },
#                     column: {
#                         pointPadding: 0.1,
#                         borderWidth: 0
#                     }
#                 },
#
#                 series: [{
#                     name: 'Transactions',
#                     type: 'spline',
#                     data: [{y : 1068969, dt : '1662940800', formattedValue : '1,068,969', friendlydate : 'Monday, September 12, 2022', price : '$1,716.53'  },{y : 1093205, dt : '1663027200', formattedValue : '1,093,205', friendlydate : 'Tuesday, September 13, 2022', price : '$1,574.56'  },{y : 1109172, dt : '1663113600', formattedValue : '1,109,172', friendlydate : 'Wednesday, September 14, 2022', price : '$1,639.60'  },{y : 1265640, dt : '1663200000', formattedValue : '1,265,640', friendlydate : 'Thursday, September 15, 2022', price : '$1,472.51'  },{y : 1311849, dt : '1663286400', formattedValue : '1,311,849', friendlydate : 'Friday, September 16, 2022', price : '$1,433.97'  },{y : 1322077, dt : '1663372800', formattedValue : '1,322,077', friendlydate : 'Saturday, September 17, 2022', price : '$1,469.05'  },{y : 1156893, dt : '1663459200', formattedValue : '1,156,893', friendlydate : 'Sunday, September 18, 2022', price : '$1,334.30'  },{y : 1138210, dt : '1663545600', formattedValue : '1,138,210', friendlydate : 'Monday, September 19, 2022', price : '$1,376.21'  },{y : 1149031, dt : '1663632000', formattedValue : '1,149,031', friendlydate : 'Tuesday, September 20, 2022', price : '$1,323.07'  },{y : 1100130, dt : '1663718400', formattedValue : '1,100,130', friendlydate : 'Wednesday, September 21, 2022', price : '$1,246.29'  },{y : 1118297, dt : '1663804800', formattedValue : '1,118,297', friendlydate : 'Thursday, September 22, 2022', price : '$1,326.15'  },{y : 1119895, dt : '1663891200', formattedValue : '1,119,895', friendlydate : 'Friday, September 23, 2022', price : '$1,326.95'  },{y : 1109206, dt : '1663977600', formattedValue : '1,109,206', friendlydate : 'Saturday, September 24, 2022', price : '$1,317.11'  },{y : 1107217, dt : '1664064000', formattedValue : '1,107,217', friendlydate : 'Sunday, September 25, 2022', price : '$1,294.72'  },{y : 1141218, dt : '1664150400', formattedValue : '1,141,218', friendlydate : 'Monday, September 26, 2022', price : '$1,336.65'  },],
#                     allowPointSelect: true,
#                     pointStart: 0
#                 }]
#             });
#         });
#     </script>
# <script type="text/javascript">
#
#         function setFocus() {
#             if (window.innerWidth > 600)
#                 $("input[name=q]").focus();
#         }
#         $(document).ready(function () {
#             //setFocus();
#         });
#     </script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'751412935f229966',m:'aYEIfjS_9KhIb_BXGugxXWW50L_O8ok1zNaiRh.ebKo-1664279959-0-AcTQX9nPvjFVuCLodjWsM8keMZ2OIi01UtghbwQWTDLOFNmCHGrwqUTzxD2H9HnzATnMu8gX9k8E0Zu49O7LU+H2L07Z3QnG8lI+H3hqC83PFzSrCKFXUZD/aUeeHohlNA==',s:[0xce8aeec473,0xa70c4b23f2],u:'/cdn-cgi/challenge-platform/h/g'};var now=Date.now()/1000,offset=14400,ts=''+(Math.floor(now)-Math.floor(now%offset)),_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/h/g/scripts/alpha/invisible.js?ts='+ts,document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
# Out:
# ^C

# %%
# Import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# Load driver

# from selenium.webdriver.chrome.options import Options
# options = Options()
# options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6ab47f67b708> in <module>
#       5 # options.add_argument("--headless")
#       6
# ----> 7 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#
# TypeError: __init__() got an unexpected keyword argument 'service'

# %%
driver.get(url)

# %% [markdown]
# Finding one specific element with XPath and class name.
#
# _Note: the browser can export these selectors._

# %%
# CSS selector not available in Selenium.
# mCSB_1_container > div:nth-child(1) > div.col-sm-8 > div > div.text-nowrap > span.d-block.mb-1.mb-sm-0 > a

my_xpath = '//*[@id="mCSB_1_container"]/div[1]/div[2]/div/div[1]/span[1]/a'

elem = driver.find_element(By.XPATH, my_xpath)

# %%
elem.text

# %%
elem = driver.find_element(By.CLASS_NAME, 'hash-tag')

elem.text

# %%
elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')

# %%
type(elements), len(elements)

# %% [markdown]
# #### All transactions
#
# Let's now get all transactions, not just what is on the home page.

# %%
url = 'https://etherscan.io/txs'

# %% [markdown]
# By visual inspection in DevTools, each row contains 3 elements:
# - transaction hash
# - from
# - to

# %%
driver.get(url)
elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7b5be5d69a49> in <module>
# ----> 1 driver.get(url)
#       2 elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
#
# NameError: name 'driver' is not defined

# %%
# Let's prepare for it.

transactions = []
toAdx = ''
fromAdx = ''

## Go through all elements containing an address or a transaction hash.
for i in range(len(elements)):
    adx = elements[i-1].text
    if i % 2 and not i % 3 == 0:
        fromAdx = adx
    if i % 3 == 0:
        toAdx = adx
        transactions.append((fromAdx, toAdx))

print(transactions)

print(len(transactions))

# %% [markdown]
# Let's build some simple statistics, counting the number of times an address receive/send a transaction.

# %%
from collections import defaultdict
sentCounts = defaultdict(int)
receivedCounts = defaultdict(int)

for i in range(len(elements)):
    adx = elements[i-1].text
    if i % 2 and not i % 3 == 0:
        sentCounts[adx] += 1
    if i % 3 == 0:
        receivedCounts[adx] += 1


print('Sent Counts')
print(sentCounts)
print('Received Counts')
print(receivedCounts)

# %%
# Support functions.

from datetime import datetime

def print_time():
    now = datetime.now()
    # dd/mm/YY H:M:S
    dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
    print("time: ", dt_string)

def update_to_from(elements):
    for i in range(len(elements)):
        adx = elements[i-1].text
        if i % 2 and not i % 3 == 0:
            sentCounts[adx] += 1
        if i % 3 == 0:
            receivedCounts[adx] += 1

# %%
# Fetch multiple pages of transactions.

url = 'https://etherscan.io/txs?ps=100&p='

# Reset counts.
sentCounts = defaultdict(int)
receivedCounts = defaultdict(int)

for i in range(1,4):
    my_url = url + str(i)
    driver.get(my_url)
    elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
    update_to_from(elements)
    print_time()

# %%
def printSorted(dic):
    sorted_dic = sorted(dic.items(), key=lambda x: x[1], reverse=True)
    for i in sorted_dic:
        print(i[0], i[1])

# %%
printSorted(sentCounts)

# %%
printSorted(receivedCounts)

# %% [markdown]
# Let's gather more pages of transactions.
#
# We can also try out different methods.

# %%
def getTxs(n=3, reset=True, showCounts=True, method="requests"):
    # Access global variables from within a function's body.
    global sentCounts
    global receivedCounts

    url = 'https://etherscan.io/txs?ps=100&p='

    # Reset counts.
    if reset:
        print('Counts reseted')
        sentCounts = defaultdict(int)
        receivedCounts = defaultdict(int)

    for i in range(1,n+1):
        my_url = url + str(i)

        if method == "requests":
            html = requests.get(my_url, headers=hdr)
            soup = BeautifulSoup(html.content, 'html.parser')
            elements = soup.select(".hash-tag")
        elif method == "selenium":
            driver.get(my_url)
            elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
        elif method == "urllib":
            req = Request(url, headers = hdr)
            page = urlopen(req)
            soup = BeautifulSoup(page, 'html.parser')
            elements = soup.select(".hash-tag")

        update_to_from(elements) 
        print_time()
    
    if showCounts:
        printSorted(sentCounts)
        printSorted(receivedCounts)

# %%
getTxs(1, method = "selenium", showCounts = False)

# %%
getTxs(1, method = "requests", showCounts = False)

# %%
getTxs(1, method = "urllib", showCounts = False)

# %%
printSorted(sentCounts)

# %%
printSorted(receivedCounts)

# %%
import pandas as pd

# %%
# Sent.
items = sentCounts.items()
df_sent = pd.DataFrame.from_dict(items)
df_sent.columns = ["address", "sent"]
df_sent.sort_values(by="sent", ascending=False)

# %%
# Sent.
items = receivedCounts.items()
df_received = pd.DataFrame.from_dict(items)
df_received.columns = ["address", "received"]
df_received.sort_values(by="received", ascending=False)

# %%
df_txs = pd.merge(df_sent, df_received, on = "address", how = "outer")
df_txs = df_txs.fillna(0)
df_txs.sort_values(by="received", ascending=False)

# %%
df_txs.plot.scatter(x='sent',
                    y='received',
                    c='DarkBlue')

# %%
import random

def jitter(x):
    return x + random.uniform(0, .5) -.25

df_txs['sent_jit'] = df_txs['sent'].apply(lambda x: jitter(x))
df_txs['received_jit'] = df_txs['received'].apply(lambda x: jitter(x))

# %%
df_txs.plot.scatter(x='sent_jit',
                    y='received_jit',
                    c='DarkBlue')
